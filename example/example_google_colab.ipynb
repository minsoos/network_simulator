# %% [markdown]
# # Introduction

# %% [markdown]
# This version of the simulator is configured to interact by default with **OpenAI**. It is important to consider that you must have an **API key** to execute the prompts that generate the conversations.
#
# The following releases of the simulator will include connection methods with LLMs from other companies such as Anthropic, Perplexity, among others.

# %% [markdown]
# # Install libraries

# %% [markdown]
# Install the following libraries.

# %%
# !sudo apt install libenchant-2-2
# !pip install network-simulator
# !pip install openai
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   aspell aspell-en dictionaries-common enchant-2 hunspell-en-us libaspell15
#   libhunspell-1.7-0 libtext-iconv-perl
# Suggested packages:
#   aspell-doc spellutils wordlist hunspell openoffice.org-hunspell
#   | openoffice.org-core libenchant-2-voikko
# The following NEW packages will be installed:
#   aspell aspell-en dictionaries-common enchant-2 hunspell-en-us libaspell15
#   libenchant-2-2 libhunspell-1.7-0 libtext-iconv-perl
# 0 upgraded, 9 newly installed, 0 to remove and 45 not upgraded.
# Need to get 1,431 kB of archives.
# After this operation, 5,501 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaspell15 amd64 0.60.8-4build1 [325 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 aspell amd64 0.60.8-4build1 [87.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 aspell-en all 2018.04.16-0-1 [299 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libenchant-2-2 amd64 2.3.2-1ubuntu2 [50.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 enchant-2 amd64 2.3.2-1ubuntu2 [13.0 kB]
# Fetched 1,431 kB in 0s (3,064 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 9.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libtext-iconv-perl.
# (Reading database ... 123595 files and directories currently installed.)
# Preparing to unpack .../0-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package libaspell15:amd64.
# Preparing to unpack .../1-libaspell15_0.60.8-4build1_amd64.deb ...
# Unpacking libaspell15:amd64 (0.60.8-4build1) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../2-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package aspell.
# Preparing to unpack .../3-aspell_0.60.8-4build1_amd64.deb ...
# Unpacking aspell (0.60.8-4build1) ...
# Selecting previously unselected package aspell-en.
# Preparing to unpack .../4-aspell-en_2018.04.16-0-1_all.deb ...
# Unpacking aspell-en (2018.04.16-0-1) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../5-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../6-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libenchant-2-2:amd64.
# Preparing to unpack .../7-libenchant-2-2_2.3.2-1ubuntu2_amd64.deb ...
# Unpacking libenchant-2-2:amd64 (2.3.2-1ubuntu2) ...
# Selecting previously unselected package enchant-2.
# Preparing to unpack .../8-enchant-2_2.3.2-1ubuntu2_amd64.deb ...
# Unpacking enchant-2 (2.3.2-1ubuntu2) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up dictionaries-common (1.28.14) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up libaspell15:amd64 (0.60.8-4build1) ...
# Setting up aspell (0.60.8-4build1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up libenchant-2-2:amd64 (2.3.2-1ubuntu2) ...
# Setting up aspell-en (2018.04.16-0-1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up enchant-2 (2.3.2-1ubuntu2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dictionaries-common (1.28.14) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# aspell-autobuildhash: processing: en [en-common].
# aspell-autobuildhash: processing: en [en-variant_0].
# aspell-autobuildhash: processing: en [en-variant_1].
# aspell-autobuildhash: processing: en [en-variant_2].
# aspell-autobuildhash: processing: en [en-w_accents-only].
# aspell-autobuildhash: processing: en [en-wo_accents-only].
# aspell-autobuildhash: processing: en [en_AU-variant_0].
# aspell-autobuildhash: processing: en [en_AU-variant_1].
# aspell-autobuildhash: processing: en [en_AU-w_accents-only].
# aspell-autobuildhash: processing: en [en_AU-wo_accents-only].
# aspell-autobuildhash: processing: en [en_CA-variant_0].
# aspell-autobuildhash: processing: en [en_CA-variant_1].
# aspell-autobuildhash: processing: en [en_CA-w_accents-only].
# aspell-autobuildhash: processing: en [en_CA-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-variant_0].
# aspell-autobuildhash: processing: en [en_GB-variant_1].
# aspell-autobuildhash: processing: en [en_US-w_accents-only].
# aspell-autobuildhash: processing: en [en_US-wo_accents-only].
# Collecting network-simulator
#   Downloading network_simulator-1.0.1-py3-none-any.whl.metadata (13 kB)
# Collecting Mesa==2.1.1 (from network-simulator)
#   Downloading Mesa-2.1.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting anytree>=2.8.0 (from network-simulator)
#   Downloading anytree-2.12.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting soil==0.20.7 (from network-simulator)
#   Downloading soil-0.20.7-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from network-simulator) (1.13.1)
# Requirement already satisfied: numpy>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from network-simulator) (1.26.4)
# Collecting pyenchant>=3.2.2 (from network-simulator)
#   Downloading pyenchant-3.2.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from Mesa==2.1.1->network-simulator) (8.1.7)
# Collecting cookiecutter (from Mesa==2.1.1->network-simulator)
#   Downloading cookiecutter-2.6.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from Mesa==2.1.1->network-simulator) (3.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from Mesa==2.1.1->network-simulator) (2.1.4)
# Collecting solara (from Mesa==2.1.1->network-simulator)
#   Downloading solara-1.37.2-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: tornado in /usr/local/lib/python3.10/dist-packages (from Mesa==2.1.1->network-simulator) (6.3.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from Mesa==2.1.1->network-simulator) (4.66.5)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.10/dist-packages (from soil==0.20.7->network-simulator) (3.1.4)
# Collecting SALib>=1.3 (from soil==0.20.7->network-simulator)
#   Downloading salib-1.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from soil==0.20.7->network-simulator) (3.7.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from soil==0.20.7->network-simulator) (6.0.2)
# Collecting tsih>=0.1.5 (from soil==0.20.7->network-simulator)
#   Downloading tsih-0.1.9-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from anytree>=2.8.0->network-simulator) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->Mesa==2.1.1->network-simulator) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->Mesa==2.1.1->network-simulator) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->Mesa==2.1.1->network-simulator) (2024.1)
# Collecting multiprocess (from SALib>=1.3->soil==0.20.7->network-simulator)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->soil==0.20.7->network-simulator) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->soil==0.20.7->network-simulator) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->soil==0.20.7->network-simulator) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->soil==0.20.7->network-simulator) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->soil==0.20.7->network-simulator) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->soil==0.20.7->network-simulator) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->soil==0.20.7->network-simulator) (3.1.2)
# Collecting binaryornot>=0.4.4 (from cookiecutter->Mesa==2.1.1->network-simulator)
#   Downloading binaryornot-0.4.4-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: python-slugify>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cookiecutter->Mesa==2.1.1->network-simulator) (8.0.4)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from cookiecutter->Mesa==2.1.1->network-simulator) (2.32.3)
# Collecting arrow (from cookiecutter->Mesa==2.1.1->network-simulator)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from cookiecutter->Mesa==2.1.1->network-simulator) (13.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2->soil==0.20.7->network-simulator) (2.1.5)
# Collecting solara-server==1.37.2 (from solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading solara_server-1.37.2-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting solara-ui==1.37.2 (from solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading solara_ui-1.37.2-py2.py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (3.15.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (5.5.6)
# Collecting jupyter-client>=7.0.0 (from solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading jupyter_client-8.6.2-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (5.10.4)
# Collecting rich-click (from solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading rich_click-1.8.3-py3-none-any.whl.metadata (7.9 kB)
# Collecting watchdog (from solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading watchdog-4.0.2-py3-none-manylinux2014_x86_64.whl.metadata (38 kB)
# Collecting watchfiles (from solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading watchfiles-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting starlette (from solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading starlette-0.38.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting uvicorn (from solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets (from solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading websockets-13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: humanize in /usr/local/lib/python3.10/dist-packages (from solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (4.10.0)
# Collecting ipyvue>=1.9.0 (from solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading ipyvue-1.11.1-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting ipyvuetify>=1.6.10 (from solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading ipyvuetify-1.10.0-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets>=7.7 in /usr/local/lib/python3.10/dist-packages (from solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (7.7.1)
# Collecting reacton>=1.7.1 (from solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading reacton-1.8.3-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: chardet>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from binaryornot>=0.4.4->cookiecutter->Mesa==2.1.1->network-simulator) (5.2.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify>=4.0.0->cookiecutter->Mesa==2.1.1->network-simulator) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter->Mesa==2.1.1->network-simulator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter->Mesa==2.1.1->network-simulator) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter->Mesa==2.1.1->network-simulator) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter->Mesa==2.1.1->network-simulator) (2024.7.4)
# Collecting types-python-dateutil>=2.8.10 (from arrow->cookiecutter->Mesa==2.1.1->network-simulator)
#   Downloading types_python_dateutil-2.9.0.20240821-py3-none-any.whl.metadata (1.9 kB)
# Collecting dill>=0.3.8 (from multiprocess->SALib>=1.3->soil==0.20.7->network-simulator)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->cookiecutter->Mesa==2.1.1->network-simulator) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->cookiecutter->Mesa==2.1.1->network-simulator) (2.16.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (3.6.8)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (3.0.11)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=7.0.0->solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (5.7.2)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=7.0.0->solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (24.0.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->cookiecutter->Mesa==2.1.1->network-simulator) (0.1.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from reacton>=1.7.1->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (4.12.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (4.23.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (5.5.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (3.7)
# Collecting pymdown-extensions (from solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading pymdown_extensions-10.9-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (3.7.1)
# Collecting h11>=0.8 (from uvicorn->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (1.2.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (71.0.4)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (3.0.47)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=7.0.0->solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (4.2.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.8.4)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (23.1.0)
# Collecting jupyter-client>=7.0.0 (from solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator)
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (1.1.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=7.0.0->solara-server==1.37.2->solara-server[dev,starlette]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.2.13)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (21.2.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.37.2->solara-ui[all]==1.37.2->solara->Mesa==2.1.1->network-simulator) (1.8.0)
# Downloading network_simulator-1.0.1-py3-none-any.whl (16 kB)
# Downloading Mesa-2.1.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.6 MB/s eta 0:00:00
# Downloading soil-0.20.7-py3-none-any.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 39.9 MB/s eta 0:00:00
# Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.1 MB/s eta 0:00:00
# Downloading pyenchant-3.2.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 4.0 MB/s eta 0:00:00
# Downloading salib-1.5.1-py3-none-any.whl (778 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.9/778.9 kB 28.2 MB/s eta 0:00:00
# Downloading tsih-0.1.9-py3-none-any.whl (14 kB)
# Downloading cookiecutter-2.6.0-py3-none-any.whl (39 kB)
# Downloading solara-1.37.2-py2.py3-none-any.whl (5.7 kB)
# Downloading solara_server-1.37.2-py2.py3-none-any.whl (3.9 kB)
# Downloading solara_ui-1.37.2-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.7 MB/s eta 0:00:00
# Downloading binaryornot-0.4.4-py2.py3-none-any.whl (9.0 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.3 MB/s eta 0:00:00
# Downloading ipyvue-1.11.1-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 57.1 MB/s eta 0:00:00
# Downloading ipyvuetify-1.10.0-py2.py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 56.6 MB/s eta 0:00:00
# Downloading reacton-1.8.3-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 6.4 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20240821-py3-none-any.whl (9.7 kB)
# Downloading rich_click-1.8.3-py3-none-any.whl (35 kB)
# Downloading starlette-0.38.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.4 MB/s eta 0:00:00
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.8 MB/s eta 0:00:00
# Downloading watchdog-4.0.2-py3-none-manylinux2014_x86_64.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 6.3 MB/s eta 0:00:00
# Downloading watchfiles-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.7/427.7 kB 24.2 MB/s eta 0:00:00
# Downloading websockets-13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 11.6 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# Downloading pymdown_extensions-10.9-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.0/251.0 kB 18.9 MB/s eta 0:00:00
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: tsih, websockets, watchdog, types-python-dateutil, pymdown-extensions, pyenchant, jedi, h11, dill, binaryornot, anytree, watchfiles, uvicorn, starlette, multiprocess, jupyter-client, arrow, SALib, rich-click, cookiecutter, reacton, ipyvue, ipyvuetify, solara-ui, solara-server, solara, Mesa, soil, network-simulator
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
# Successfully installed Mesa-2.1.1 SALib-1.5.1 anytree-2.12.1 arrow-1.3.0 binaryornot-0.4.4 cookiecutter-2.6.0 dill-0.3.8 h11-0.14.0 ipyvue-1.11.1 ipyvuetify-1.10.0 jedi-0.19.1 jupyter-client-7.4.9 multiprocess-0.70.16 network-simulator-1.0.1 pyenchant-3.2.2 pymdown-extensions-10.9 reacton-1.8.3 rich-click-1.8.3 soil-0.20.7 solara-1.37.2 solara-server-1.37.2 solara-ui-1.37.2 starlette-0.38.2 tsih-0.1.9 types-python-dateutil-2.9.0.20240821 uvicorn-0.30.6 watchdog-4.0.2 watchfiles-0.23.0 websockets-13.0
# Collecting openai
#   Downloading openai-1.42.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Downloading openai-1.42.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.9/362.9 kB 3.4 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.5 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: jiter, httpcore, httpx, openai
# Successfully installed httpcore-1.0.5 httpx-0.27.0 jiter-0.5.0 openai-1.42.0

# %% [markdown]
# Clone github repository associated with the simulator.

# %%
# !git clone https://github.com/minsoos/network_simulator.git
# Out:
# Cloning into 'network_simulator'...
# remote: Enumerating objects: 344, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 344 (delta 67), reused 72 (delta 48), pack-reused 233 (from 1)
# Receiving objects: 100% (344/344), 731.64 KiB | 5.38 MiB/s, done.
# Resolving deltas: 100% (175/175), done.

# %% [markdown]
# Import libraries.

# %%
import subprocess
import os
import time

from network_simulator import make_yml, make_network_agents_yml
from network_simulator import get_pivoted_data, get_type_agents
from network_simulator import POST_TEMPLATE, REPLY_TEMPLATE, INSTRUCTIONS_TEMPLATE
from network_simulator import transform_time
from network_simulator import correctness_prompt, correctness_percentage
from anytree import Node, RenderTree, LevelOrderIter
from network_simulator import Post
from network_simulator.gpt3_5 import send_prompt_openai as send_prompt

import openai

# %% [markdown]
# # Define the parameters for the simulation

# %%
folder = os.path.join('network_simulator/schema')
name_simulation = 'simulation_tutorial'

network_agents_parameters = {
    "default": {
        "id_message": "NaN",
        "has_tv": "false",
        "cause": -1,
        "method": "NaN",

        "type": "dumb",
        "response": "NaN",
        "stance": "agree",
        "repost": "NaN",
        "parent_id": "NaN"

    },

    "DumbViewer": [
        {"weight": 2, "type": "dumb"},
        {"weight": 2, "type": "dumb", "has_tv": "true"}
    ],
    "HerdViewer": [
        {"weight": 2, "type": "herd", "stance": "against"},
        {"weight": 2, "type": "herd", "has_tv": "true"}
    ],
    "WiseViewer": [
        {"weight": 1, "type": "wise", "stance": "against"},
        {"weight": 1, "type": "wise", "has_tv": "true", "stance": "neutral"}
    ],

}

INTERVALS = 100
parameters = {
    "default_state": "{}",
    "load_module": "schema",
    "environment_agents": "[]",
    "environment_class": "schema.NewsEnvironmentAgent",
    "environment_params": {
        "prob_neighbor_spread": 0.05,
        "prob_tv_spread": 0.05,
        "prob_neighbor_cure": 0.006,
        "prob_backsliding": 0.05,
        "prob_dead": 0.001,
        "prob_repost": 0.8,
        "mean_time_connection": 10,
        "var_time_connection": 30
    },
    "interval": 1,
    "max_time": INTERVALS,
    "name": name_simulation,
    "network_params": {
        "generator": "barabasi_albert_graph",
        "n": 20,
        "m": 5
    },
    "num_trials": 1
}

prob_response = {"dumb": {"support": 0.4, "deny": 0.3, "question": 0, "comment": 0.2},
                "herd": {"support": 0.25, "deny": 0.25, "question": 0.25, "comment": 0.25},
                "wise": {"support": 0.2, "deny": 0.2, "question": 0.3, "comment": 0.3}
                }

# %% [markdown]
# Create the .yml file that will be used by SOIL.

# %%
types = list(prob_response.keys())
responses = list( prob_response[types[0]].keys() )
for type_i in types:
    for response in responses:
        name_i = f"prob_{type_i}_{response}"
        prob_i = prob_response[type_i][response]
        # Here, we set each probability
        parameters["environment_params"][name_i] = prob_i

parameters_i = parameters.copy()
network_agents_parameters_i = network_agents_parameters.copy()
data = make_yml(parameters_i)
data += make_network_agents_yml(network_agents_parameters_i)

os.path.join(folder, f'{name_simulation}.yml')

yml_path = os.path.join(folder, f'{name_simulation}.yml') # YML path
with open(yml_path, 'w') as file:
    file.write(data)

# %% [markdown]
# # Run SOIL

# %%
command = "soil"
start = time.time()

output = subprocess.check_output([command, yml_path])
end = time.time()
seconds_simulation = str(end-start)
print("SIMULATION'S SECONDS:", seconds_simulation)
# Out:
# SIMULATION'S SECONDS: 3.3409204483032227

# %%
name_simulation = 'simulation_tutorial'

analysis_path = os.path.join('soil_output', name_simulation)
sql_table_path = f'{name_simulation}_trial_0.sqlite'

attributes = ['cause', 'method', 'response', 'stance', 'repost']

data = get_pivoted_data(analysis_path, sql_table_path, attributes)
dict_agents = get_type_agents(analysis_path, sql_table_path)

# %% [markdown]
# # Define root message

# %%
NEWS = 'They dictate preventive detention for Pablo Mackenna after being involved in a traffic accident while intoxicated in Las Condes. '
NEWS_BODY = '''
According to the information being handled, Mackenna crashed an executive taxi on Avenida Presidente Errázuriz and Calle Sánchez Fontecilla, causing serious damage to the other vehicle and leaving one person injured. When performing the breathalyzer, he returned 1.27 grams of alcohol per liter of blood. "We have to look at the conduct of the accused and the way in which he puts the lives of third parties at risk, which actually happened today," said Judge Acevedo. She added that "he hit a taxi driver, that the vehicle is his source of work, therefore, he will be unable to work, in addition to the license he has... he also injured another person." . Likewise, she emphasized that Mackenna crossed the red light, which is why she "committed a traffic violation, in addition to driving while intoxicated." "He will agree to the request of the Prosecutor's Office, and preventive detention will be ordered," said the judge, specifying that an investigation period of 90 days was determined.
'''
SHOW_TREE = True

# %%
root = Post(0, message=NEWS, step=0, post_template=POST_TEMPLATE,
             reply_template=REPLY_TEMPLATE,
             instructions_template=INSTRUCTIONS_TEMPLATE, news=NEWS)

# %%
TIME_BEG = "10:00"
TIME_END = "23:00"

list_nodes = [root]
num_real_messages = 0
for i in range(len(data)):
    aux = data[i]
    owner = int(aux[0])
    step = int(aux[1])
    step = transform_time(step, TIME_BEG, TIME_END)
    id_message = int(aux[2])
    parent = list_nodes[int(aux[3])]
    state = aux[4] #unused
    attr_dict = {}
    for index, attr in enumerate(attributes):
        index +=5
        attr_dict[attr] = aux[index]

    type_agent = dict_agents[owner]

    ### Specific for repost attribute
    if attr_dict["repost"] in ["0", "1"]:
        attr_dict["repost"] = bool(int(attr_dict["repost"]))
    else:
        print(data[i])
        print(attr_dict["repost"])
        raise ValueError("Error repost format")

    if not attr_dict["repost"]:
        num_real_messages += 1
    ###

    message = ''
    news_i = NEWS
    if type_agent == "wise":
        news_i += NEWS_BODY

    list_nodes.append(Post(name=id_message, parent=parent, owner=owner, step=step, message=message, type_agent=type_agent,
                             post_template=POST_TEMPLATE, reply_template=REPLY_TEMPLATE,
                             instructions_template=INSTRUCTIONS_TEMPLATE, news=news_i,
                             **attr_dict
                             )
    )

# %% [markdown]
# # Create messages

# %%
API_KEY = "insert API KEY"

client = openai.OpenAI(api_key=API_KEY)

TEMPERATURE = 1.0
list_prompts = []
i_tot = 0
i = 0
num_llm_errors = 0
MAX_LLM_ERRORS = 15
t = time.time()
t_0 = t

time_list = [0 for _ in range(num_real_messages)]
for node_i in LevelOrderIter(root):
    i_tot += 1
    if node_i == root:
        continue
    elif node_i.repost:
        continue
    i += 1
    instructions, prompt = node_i.get_prompt(language='english',
                min_caract=130, max_caract=250,
                user_description='average toxic and angry social media user')
    error_llm = True
    while error_llm:
        try:
            answer = send_prompt(client, instructions, prompt, temp=TEMPERATURE, max_tokens=1000, timeout=40)
            error_llm = False
        except Exception as err:
            print(f"Error encountered (message {i}/{num_real_messages}):", err)
            print("Instrucciones:", instructions)
            print("prompt", prompt)
            time.sleep(2)
            num_llm_errors += 1
            error_llm = True
            if num_llm_errors >= MAX_LLM_ERRORS:
                print("Max Errors reached. Local break run")
                break
    if num_llm_errors >= MAX_LLM_ERRORS:
        print("Max Errors reached. Break run")
        break
    correctness = correctness_percentage(answer)
    while correctness >= 0.2:
        print("Correction")
        correction_prompt = correctness_prompt(node_i.news, answer)
        print(correction_prompt)
        answer = send_prompt(client, instructions, correction_prompt, temp=TEMPERATURE, max_tokens=1000, timeout=40)
        correctness = correctness_percentage(answer)

    node_i.set_message(answer)
    list_prompts.append((node_i.name, prompt))
    t_aux = time.time()
    print(f"TIME: {t_aux-t}. Iter tot: {i_tot}. n. message: {i}")
    time_list[i-1] = t
    t = t_aux

print("TOTAL TIME:", t-t_0)
# Out:
# TIME: 1.0158486366271973. Iter tot: 5. n. message: 1
# TIME: 0.6690773963928223. Iter tot: 6. n. message: 2
# TIME: 0.943396806716919. Iter tot: 8. n. message: 3
# TIME: 0.9126379489898682. Iter tot: 9. n. message: 4
# TIME: 0.7346704006195068. Iter tot: 11. n. message: 5
# TIME: 0.8900735378265381. Iter tot: 12. n. message: 6
# TIME: 0.7833116054534912. Iter tot: 14. n. message: 7
# TIME: 0.7695755958557129. Iter tot: 18. n. message: 8
# TIME: 0.8203415870666504. Iter tot: 19. n. message: 9
# TIME: 0.7964117527008057. Iter tot: 20. n. message: 10
# TIME: 0.8461728096008301. Iter tot: 21. n. message: 11
# TIME: 0.806265115737915. Iter tot: 22. n. message: 12
# TIME: 0.7984163761138916. Iter tot: 23. n. message: 13
# TIME: 0.760814905166626. Iter tot: 24. n. message: 14
# TIME: 0.7745134830474854. Iter tot: 25. n. message: 15
# TIME: 0.8147408962249756. Iter tot: 29. n. message: 16
# TIME: 0.887547492980957. Iter tot: 31. n. message: 17
# TIME: 0.7775382995605469. Iter tot: 32. n. message: 18
# TIME: 1.0147485733032227. Iter tot: 33. n. message: 19
# TIME: 0.8298423290252686. Iter tot: 35. n. message: 20
# TIME: 0.7957944869995117. Iter tot: 37. n. message: 21
# TIME: 1.0056276321411133. Iter tot: 39. n. message: 22
# TIME: 2.036755084991455. Iter tot: 40. n. message: 23
# TIME: 0.8481886386871338. Iter tot: 41. n. message: 24
# TIME: 0.8079319000244141. Iter tot: 42. n. message: 25
# TIME: 0.8254926204681396. Iter tot: 43. n. message: 26
# TIME: 0.9234778881072998. Iter tot: 44. n. message: 27
# TIME: 0.8618373870849609. Iter tot: 45. n. message: 28
# TIME: 0.8127872943878174. Iter tot: 46. n. message: 29
# TIME: 0.8214483261108398. Iter tot: 47. n. message: 30
# TIME: 0.769909143447876. Iter tot: 48. n. message: 31
# TIME: 0.7457003593444824. Iter tot: 49. n. message: 32
# TIME: 0.7338652610778809. Iter tot: 50. n. message: 33
# TIME: 0.9162812232971191. Iter tot: 51. n. message: 34
# TIME: 0.9310526847839355. Iter tot: 52. n. message: 35
# TIME: 0.8985154628753662. Iter tot: 53. n. message: 36
# TIME: 0.88950514793396. Iter tot: 54. n. message: 37
# TIME: 0.9589500427246094. Iter tot: 55. n. message: 38
# TIME: 0.775773286819458. Iter tot: 56. n. message: 39
# TIME: 0.8408379554748535. Iter tot: 57. n. message: 40
# TIME: 1.0045983791351318. Iter tot: 58. n. message: 41
# TIME: 0.7927861213684082. Iter tot: 59. n. message: 42
# TIME: 0.8576552867889404. Iter tot: 60. n. message: 43
# TIME: 0.917938232421875. Iter tot: 61. n. message: 44
# TIME: 0.8610124588012695. Iter tot: 62. n. message: 45
# TIME: 0.8329458236694336. Iter tot: 63. n. message: 46
# TIME: 1.0724656581878662. Iter tot: 64. n. message: 47
# TIME: 0.8707678318023682. Iter tot: 65. n. message: 48
# TIME: 0.8295748233795166. Iter tot: 66. n. message: 49
# TIME: 0.830775260925293. Iter tot: 67. n. message: 50
# TIME: 0.8526544570922852. Iter tot: 68. n. message: 51
# TIME: 1.0086255073547363. Iter tot: 69. n. message: 52
# TIME: 1.1466648578643799. Iter tot: 70. n. message: 53
# TIME: 0.8233907222747803. Iter tot: 72. n. message: 54
# TIME: 0.7513918876647949. Iter tot: 73. n. message: 55
# TIME: 0.8537843227386475. Iter tot: 74. n. message: 56
# TIME: 0.8435051441192627. Iter tot: 75. n. message: 57
# TIME: 0.9364070892333984. Iter tot: 76. n. message: 58
# TIME: 0.9415848255157471. Iter tot: 77. n. message: 59
# TIME: 0.8025212287902832. Iter tot: 78. n. message: 60
# TIME: 0.8294343948364258. Iter tot: 79. n. message: 61
# TIME: 0.735004186630249. Iter tot: 80. n. message: 62
# TIME: 0.8957526683807373. Iter tot: 81. n. message: 63
# TIME: 0.8195619583129883. Iter tot: 82. n. message: 64
# TIME: 0.937603235244751. Iter tot: 83. n. message: 65
# TIME: 0.6634597778320312. Iter tot: 84. n. message: 66
# TIME: 0.9773128032684326. Iter tot: 85. n. message: 67
# TIME: 0.9091682434082031. Iter tot: 86. n. message: 68
# TIME: 0.869163990020752. Iter tot: 87. n. message: 69
# TIME: 1.0657994747161865. Iter tot: 88. n. message: 70
# TIME: 0.7589495182037354. Iter tot: 89. n. message: 71
# TOTAL TIME: 62.13793754577637

# %% [markdown]
# # Show propagation cascade

# %%
if SHOW_TREE:
    for pre, _, node in RenderTree(root):
        if node.name == 0:
            print(f"{pre}NEWS: {node.message}")
            continue

        if node.repost:
            message = "repost"
        else:
            message = "'"+node.message+"'"
        print(f"{pre}{node.owner}<<{node.name}>> (t={node.step})({node.type_agent})({node.parent.name}) {message}")
# Out:
# NEWS: They dictate preventive detention for Pablo Mackenna after being involved in a traffic accident while intoxicated in Las Condes.
# ├── 13<<1>> (t=10:28)(wise)(0) repost
# │   ├── 19<<3>> (t=11:27)(dumb)(1) repost
# │   │   └── 9<<11>> (t=13:46)(dumb)(3) 'Yeah, he definitely needs to face the consequences of his actions. Drinking and driving is a serious issue that puts lives at risk. Hopefully, this serves as a wake-up call for everyone to think twice before getting behind the wheel after drinking. 🚫🍺'
# │   │       ├── 4<<14>> (t=14:38)(dumb)(11) repost
# │   │       ├── 16<<15>> (t=14:36)(wise)(11) 'Absolutely, drinking and driving is never okay. 🚫🍺 It's alarming how one wrong decision can have such severe consequences. Let's all remember to prioritize safety on the roads and make responsible choices.'
# │   │       │   ├── 4<<16>> (t=14:45)(dumb)(15) 'Yeah, totally agree! 🚫🍺 It's shocking how easily things can go wrong when driving under the influence. Safety first, always. Let's all be responsible and prevent such tragedies from happening.'
# │   │       │   └── 20<<25>> (t=15:18)(dumb)(15) 'I totally agree! Drinking and driving is a big no-no. 🚫🍺 It's scary how a bad choice can lead to serious trouble. Safety first on the roads, always. Let's be responsible and avoid accidents.'
# │   │       │       ├── 17<<33>> (t=16:22)(herd)(25) repost
# │   │       │       └── 20<<38>> (t=16:44)(dumb)(25) 'I agree 100%! Drinking and driving is just not worth it. The consequences can be so serious. Let's all make smart choices and keep our roads safe for everyone. Safety always comes first! 🚗🔒'
# │   │       ├── 6<<17>> (t=14:43)(dumb)(11) repost
# │   │       │   └── 14<<28>> (t=15:44)(wise)(17) repost
# │   │       ├── 20<<18>> (t=14:44)(dumb)(11) repost
# │   │       │   └── 18<<20>> (t=15:07)(wise)(18) repost
# │   │       │       └── 15<<24>> (t=15:15)(dumb)(20) repost
# │   │       ├── 10<<19>> (t=14:51)(dumb)(11) repost
# │   │       │   ├── 2<<31>> (t=15:59)(herd)(19) repost
# │   │       │   ├── 6<<44>> (t=17:52)(dumb)(19) 'Absolutely, drinking and driving is no joke. People need to realize the risks involved. It's not just about the legal consequences but also the danger it poses to others. Let's hope this makes everyone more aware and responsible before grabbing those car keys. 🚗🚫'
# │   │       │   │   ├── 8<<52>> (t=18:17)(dumb)(44) 'You're totally right. Drinking and driving is serious stuff. It's not just about the law; it's about keeping everyone safe. Hopefully, this incident serves as a wake-up call for everyone. Let's all make better choices and ensure everyone's safety on the road. 🚫🚗'
# │   │       │   │   ├── 4<<64>> (t=19:10)(dumb)(44) 'I totally agree. Drunk driving is a serious issue that puts so many lives at risk. It's not worth risking your life or someone else's just to avoid calling a cab or a sober friend for a ride. Hopefully, this news serves as a wakeup call for everyone to be more responsible behind the wheel. 🚫🍻'
# │   │       │   │   │   ├── 2<<71>> (t=20:37)(herd)(64) 'I couldn't agree more. It's frustrating how some people still choose to drink and drive, risking lives just for convenience. It's crucial to be responsible and make the right choice before getting behind the wheel. Let's all stay safe on the roads! 🛑🚗'
# │   │       │   │   │   ├── 12<<75>> (t=21:05)(herd)(64) 'Why are people still driving drunk in this day and age? It's insane how some still make that reckless choice. Can't believe some folks prioritize saving a few bucks over lives. Stay safe, folks! 🚨 #NoExcuses'
# │   │       │   │   │   │   └── 7<<87>> (t=22:50)(herd)(75) 'That's crazy! It's unbelievable how some still choose to drink and drive, risking lives just to save a few bucks. Stay safe out there, people! 🚫🍺 #SafetyFirst'
# │   │       │   │   │   ├── 13<<83>> (t=21:53)(wise)(64) 'Absolutely! It's shocking how some people still choose to drive under the influence. It's a selfish and dangerous decision that can have devastating consequences. We all need to take responsibility and never drive drunk. Let's keep our roads safe for everyone. 🚗✋🏼'
# │   │       │   │   │   └── 3<<88>> (t=22:53)(dumb)(64) 'I couldn't agree more! Driving under the influence is no joke. It's scary how many lives are affected by this reckless behavior. Better safe than sorry, always have a plan for a safe ride home. Let's all drive responsibly and keep our roads safe. 🚗💥'
# │   │       │   │   ├── 16<<66>> (t=19:33)(wise)(44) 'Totally agree with you! Drinking and driving is a serious issue with real consequences. It's not worth risking lives for a night out. Hopefully, this serves as a wake-up call for everyone 🚫🍺.'
# │   │       │   │   ├── 13<<77>> (t=21:21)(wise)(44) 'I totally agree! Drinking and driving is no joke. It's not just about the legal consequences but the real danger it poses to others. Let's all be more responsible and think twice before getting behind the wheel after drinking. 🚫🚗'
# │   │       │   │   │   └── 2<<81>> (t=21:44)(herd)(77) 'I totally agree with you! Drinking and driving is a serious issue. It's not just about the punishment but the risks to everyone on the road. We all need to be responsible. 🚫🚗'
# │   │       │   │   └── 3<<82>> (t=21:52)(dumb)(44) 'Totally agree. Drinking and driving is a serious issue. Everyone should think twice before getting behind the wheel after drinking. Let's all stay safe on the roads and make responsible choices. 🚫🍺 #DriveSafe'
# │   │       │   ├── 11<<49>> (t=18:06)(herd)(19) repost
# │   │       │   │   └── 17<<51>> (t=18:08)(herd)(49) 'Absolutely, you're spot on. This guy needs to own up to what he did. Drinking and driving is no joke, man. It's scary to think how many lives could have been in danger. Hopefully, this whole thing makes people think twice before driving under the influence. Safety first always! 🚗'
# │   │       │   │       ├── 8<<53>> (t=18:22)(dumb)(51) 'I totally agree with you. It's so reckless to drink and drive, it's just not worth the risk. Hopefully, this situation serves as a wake-up call to everyone out there. Safety on the road is so important. 🚦'
# │   │       │   │       └── 15<<84>> (t=21:55)(dumb)(51) 'I totally agree with you. Drinking and driving is a serious matter. It's alarming to think about the potential consequences. Let's hope this serves as a wake-up call to everyone. Safety should always come first! 🚫🍺🚗'
# │   │       │   ├── 9<<65>> (t=19:26)(dumb)(19) 'Yeah, totally agree with you. It's crucial for people to understand the dangers of drunk driving. It's not just about facing the consequences but also protecting lives. We all need to be responsible and make smart choices when it comes to alcohol and driving. 🚗🚫'
# │   │       │   └── 8<<74>> (t=21:07)(dumb)(19) 'Totally agree! It's so reckless to drink and drive, jeopardizing lives. Laws are there to keep us safe. Let's all make smarter choices and avoid such dangerous behaviors. This should be a reminder for everyone. 🚗🛑'
# │   │       │       └── 8<<79>> (t=21:39)(dumb)(74) 'I totally agree with you! Drinking and driving is beyond irresponsible. We all need to take the laws seriously and avoid risking lives. Let's make the roads safer for everyone. This incident should serve as a wake-up call for all of us. 🚫🍻'
# │   │       ├── 3<<26>> (t=15:38)(dumb)(11) 'Absolutely, drinking and driving is no joke. It's about time people realize the dangers involved. Hopefully, this incident will make everyone think twice before making such a reckless decision. 🚫🍺'
# │   │       │   └── 11<<59>> (t=18:44)(herd)(26) 'I totally agree. Drinking and driving is dangerous. It's shocking how some still risk it. Hopefully, this serves as a wake-up call for everyone. Safety first, always! 🚫🍻'
# │   │       │       ├── 18<<62>> (t=18:51)(wise)(59) 'I completely agree. It's unbelievable how some people still think it's okay to drink and drive. This incident should make everyone think twice before putting themselves and others in danger. Safety should always come first! 🛑🚗'
# │   │       │       │   └── 7<<78>> (t=21:33)(herd)(62) 'No way! Are we really doing this again? It's 2021, people should know better by now! Drinking and driving is just plain stupid. No excuses! Safety first always! 🙅‍♂️🚫🍻'
# │   │       │       │       └── 14<<85>> (t=22:24)(wise)(78) 'I agree! It's frustrating seeing this happen in 2021. Safety should always come first. Drinking and driving is totally irresponsible. No excuses for putting others at risk. 🙅‍♂️🚫🍻'
# │   │       │       ├── 9<<69>> (t=19:59)(dumb)(59) 'Absolutely! Drinking and driving is no joke. It's scary how some still take that risk. This incident should definitely make people think twice before getting behind the wheel after drinking. Safety should always come first! 🚗🚫'
# │   │       │       └── 18<<80>> (t=21:38)(wise)(59) 'Absolutely! Drinking and driving is never okay. It's alarming how some still take that risk. This should be a lesson for all to prioritize safety on the road. 🚗 Safety always comes first! 🛑'
# │   │       ├── 7<<29>> (t=15:47)(herd)(11) 'Nah, this is all blown out of proportion. People make mistakes, give them a break! Who hasn't messed up? It's not like he's the first person to drink and drive. Let's not act like saints here. 🙄'
# │   │       ├── 14<<37>> (t=16:42)(wise)(11) 'Totally agree! It's crazy how some still think it's okay to drink and drive. 🤦‍♂️ Let's hope this makes people realize the importance of being responsible on the road. 🚗 #SafetyFirst'
# │   │       └── 16<<54>> (t=18:25)(wise)(11) 'Totally agree! Drinking and driving is no joke. Real consequences for real careless actions. People need to wise up, no excuses for putting lives in danger.🚫🍻'
# │   ├── 16<<4>> (t=11:29)(wise)(1) 'That's what he deserves! No special treatment for anyone breaking the law 🚨. Drinking and driving is just plain reckless! Hopefully, this sends a strong message to everyone. #NoExcuses #JusticeServed'
# │   ├── 16<<5>> (t=12:54)(wise)(1) 'Well, serves him right! People like him need to face consequences for their actions. Driving drunk and causing accidents is no joke.🚗⛔️ #NoExcuses'
# │   │   └── 3<<6>> (t=13:22)(dumb)(5) repost
# │   │       └── 19<<12>> (t=14:05)(dumb)(6) 'Yeah, totally agree! It's about time these celebrities face the music for their reckless behavior. Driving under the influence is just not cool. Hope this serves as a lesson to others. #NoExcuses 🚫🍺'
# │   ├── 9<<7>> (t=13:24)(dumb)(1) repost
# │   │   └── 16<<9>> (t=13:35)(wise)(7) 'What a mess! Can't believe some people still choose to drive under the influence. Hope justice is served and others learn from this. Stay safe on the roads, folks! 🚗'
# │   │       └── 3<<13>> (t=14:31)(dumb)(9) 'Yeah, it's unbelievable that some folks still take the risk of driving drunk. It's reckless and dangerous. Let's hope justice prevails and acts as a wake-up call for others. Stay safe out there, everyone! 🚗'
# │   │           ├── 1<<21>> (t=15:12)(herd)(13) repost
# │   │           │   ├── 13<<23>> (t=15:17)(wise)(21) 'Absolutely right! It's insane to think people still drive under the influence. So reckless and puts innocent lives at risk. Hopefully, this serves as a lesson for everyone. Stay safe on the roads, folks! 🚦'
# │   │           │   │   ├── 15<<32>> (t=16:01)(dumb)(23) 'Totally agree! Driving drunk is just plain irresponsible. It's terrifying how some still don't get it. Let's hope this sends a strong message. Be safe out there, everyone! 🚗 #dontdrinkanddrive'
# │   │           │   │   ├── 12<<34>> (t=16:37)(herd)(23) 'How about mind your business? People make mistakes, no need to act all high and mighty. We all mess up sometimes. Don't act like you're perfect. Everyone deserves a second chance. Stop being so judgmental. 🙄'
# │   │           │   │   │   ├── 14<<61>> (t=18:50)(wise)(34) 'Hey, everyone messes up, but crashing a taxi and injuring someone while drunk driving is no joke. It's about taking responsibility for your actions and facing the consequences. It's not about being perfect, it's about being accountable. 🤷‍♂️'
# │   │           │   │   │   └── 2<<67>> (t=19:39)(herd)(34) 'Exactly! People can be so quick to judge without knowing the full story. We all make mistakes. It's important to show some empathy and understanding. Let's hope everyone involved gets the support they need. 🤝'
# │   │           │   │   └── 8<<58>> (t=18:43)(dumb)(23) 'I totally agree! Driving drunk is just plain dangerous. It's scary to think about the consequences. Let's all be responsible behind the wheel. Stay safe out there, everyone! 🚗 #dontdrinkanddrive'
# │   │           │   │       ├── 13<<60>> (t=18:53)(wise)(58) 'Absolutely! Driving under the influence is reckless and selfish. It's alarming how one wrong decision can have devastating effects on others. Responsibility is key when behind the wheel. Let's prioritize safety for everyone on the road. 🚦 #DriveSafe'
# │   │           │   │       │   └── 14<<73>> (t=21:01)(wise)(60) 'Totally agree! Driving drunk is just plain stupid and dangerous. One bad choice can mess up so many lives. Safety first, always! 🚗 #StaySafe'
# │   │           │   │       └── 15<<72>> (t=20:34)(dumb)(58) 'I agree with you! Driving under the influence is so reckless and dangerous. It's crucial for everyone to be responsible on the road. Let's make sure we're all keeping ourselves and others safe out there. #besafe 🚦'
# │   │           │   ├── 16<<27>> (t=15:36)(wise)(21) 'I totally agree! Driving drunk is so irresponsible and puts everyone at risk. Let's hope this serves as a lesson to others. Stay safe on the roads, folks! 🚦'
# │   │           │   │   └── 2<<41>> (t=17:39)(herd)(27) 'I agree 100%! Driving under the influence is just not worth it. It's dangerous for everyone on the road. Hopefully, this serves as a wake-up call. Let's all make safer choices and look out for each other. Stay safe out there! 🚗🔴'
# │   │           │   ├── 14<<35>> (t=16:33)(wise)(21) 'Absolutely! It's so irresponsible to drink and drive, putting others in danger. Hopefully, this serves as a lesson to everyone. Safety first, always! 🚫🍻 Drive safe, folks! #StaySafe #NoDrunkDriving'
# │   │           │   │   └── 7<<36>> (t=16:40)(herd)(35) 'No way! This whole thing is blown out of proportion. People act like they've never made mistakes. Don't act all high and mighty. None of us are perfect. It's not like this is a common thing. Let him sort it out. No need for all the drama. 😡🤷‍♂️'
# │   │           │   │       └── 20<<43>> (t=17:32)(dumb)(36) 'I get what you're saying, mistakes happen. No one's perfect, right? People are quick to judge. Let's give him a chance to make it right. Drama's unnecessary. Let's hope he learns from this. 😤🤷‍♂️'
# │   │           │   │           └── 20<<63>> (t=18:52)(dumb)(43) 'Yeah, totally agree mistakes happen, but drinking and driving is a big no-no. He needs to face the consequences and learn from this mess. Drama aside, safety should come first. Hopefully, he'll make things right and never repeat this mistake. 🚗🚫'
# │   │           │   ├── 6<<42>> (t=17:36)(dumb)(21) 'Yeah, totally agree! Driving drunk is just beyond irresponsible. Hopefully, this arrest sends a strong message. It's scary to think about the consequences of such reckless behavior. Let's all stay safe on the roads, folks! 🚦'
# │   │           │   ├── 9<<56>> (t=18:33)(dumb)(21) 'I totally agree with you! Driving drunk is just not worth it. It's insane that people still do it. Let's hope this serves as a lesson to everyone out there. Stay safe and never ever drink and drive! 🚫🍻#SafetyFirst'
# │   │           │   ├── 9<<57>> (t=18:35)(dumb)(21) 'I totally agree! Driving under the influence is so dangerous and irresponsible. It's not just about getting caught; it's about the lives that are at risk. Let's hope this serves as a lesson for everyone. Stay safe on the roads, folks! 🚫🍻🚗'
# │   │           │   └── 1<<76>> (t=21:19)(herd)(21) 'I totally agree! Driving drunk is not only risking your own life but others too. It's scary how some still don't get it. Hopefully, this case makes people think twice before getting behind the wheel after drinking. Stay safe, everyone! 🚫🍻'
# │   │           └── 4<<22>> (t=15:16)(dumb)(13) 'I totally agree! Driving drunk is so dangerous and irresponsible. Hopefully, this case serves as a warning to others. Let's all make the smart choice and stay safe on the roads. 🚦 #SafetyFirst'
# │   │               ├── 19<<30>> (t=15:50)(dumb)(22) 'Totally agree! Driving drunk is reckless and risky, no excuses! Let's all be responsible behind the wheel and keep our roads safe for everyone. Hope this serves as a wakeup call! 🚗 #DriveSafe'
# │   │               │   ├── 8<<39>> (t=16:52)(dumb)(30) repost
# │   │               │   │   ├── 7<<45>> (t=17:49)(herd)(39) 'Not true! Stop spreading false news! There's no evidence Pablo Mackenna was involved in any accident. Don't jump to conclusions without facts. Let's be fair and not quick to judge. 🤬 #FactsMatter'
# │   │               │   │   │   └── 4<<47>> (t=18:01)(dumb)(45) 'I get the frustration but sadly, it's true. The facts are out there. Let's not defend the indefensible. It's important to face the consequences of our actions. Let's hope everyone involved learns from this and makes better choices in the future. #Accountability 🚗✋'
# │   │               │   │   └── 15<<50>> (t=18:10)(dumb)(39) 'I totally agree with you! Driving under the influence is so dangerous and irresponsible. Let's all make sure to be responsible and keep our roads safe for everyone. Hopefully, this serves as a wakeup call to prioritize safety always. 🚗 #DriveSafe'
# │   │               │   │       ├── 7<<55>> (t=18:28)(herd)(50) 'Sorry, but I don't buy it. Are we turning a blind eye to real issues here? Intoxicated driving is no joke but where's the fairness in how this is being addressed? It's like picking favorites. 🙄 #NotConvinced'
# │   │               │   │       │   └── 20<<70>> (t=20:19)(dumb)(55) 'Intoxicated driving is a serious issue affecting many lives. It's important to prioritize safety and accountability for all. Let's support fair consequences for everyone involved. 🚫🍻 #SafetyFirst'
# │   │               │   │       └── 14<<68>> (t=19:47)(wise)(50) 'Absolutely! Totally agree, driving drunk is a recipe for disaster. Safety should always come first on the road. Let's all be responsible drivers and look out for each other. This incident is a stark reminder of the dangers of driving under the influence. #DriveSafe 🚫🍻'
# │   │               │   ├── 17<<40>> (t=16:59)(herd)(30) 'I totally agree! Driving under the influence is just plain irresponsible. We all gotta be careful on the road. This should be a lesson for everyone. Stay safe out there behind the wheel! 🚦 #DriveResponsibly'
# │   │               │   └── 7<<86>> (t=22:36)(herd)(30) 'No way! Everyone makes mistakes, don't pretend you're perfect. Stop judging and preaching. The media blows things out of proportion. It's not the end of the world. 🙄 #ChillOut'
# │   │               └── 16<<46>> (t=17:51)(wise)(22) 'Absolutely! Driving under the influence is just reckless and selfish. It's scary to think about the consequences of such actions. Let's all be responsible and prioritize safety on the roads. #LearnFromMistakes 🚗 #DriveSober'
# │   │                   └── 16<<48>> (t=17:57)(wise)(46) 'Totally agree! Driving drunk is totally irresponsible and dangerous. It's scary how one bad decision can have such serious consequences. Safety on the road should always come first. #StaySafe #Responsibility 🚦🚗'
# │   └── 13<<8>> (t=13:35)(wise)(1) 'What an irresponsible and dangerous behavior! People should not drive under the influence. Justice needs to be served. Stay safe on the roads, folks. 🚗🚫'
# │       └── 9<<10>> (t=13:38)(dumb)(8) 'I totally agree! Driving drunk is just reckless! 🤬 Justice should definitely step in when safety is at risk. Let's all be responsible behind the wheel and not put others in danger. Stay safe out there, everyone! 🚗💨'
# └── 16<<2>> (t=11:10)(wise)(0) repost

# %% [markdown]
# # Create dataframe with messages

# %%
from output_dataframe import create_output_df

# %%
df = create_output_df.get_dataframe(list_nodes)
df
# Out:
#    target_step  source_node  iteration  \
# 0        10:28            0          1
# 1        11:10            0          2
# 2        11:27            1          3
# 3        11:29            1          4
# 4        12:54            1          5
# ..         ...          ...        ...
# 83       21:55           51         84
# 84       22:24           78         85
# 85       22:36           30         86
# 86       22:50           75         87
# 87       22:53           64         88
#
#                                        target_message interaction   stance  \
# 0                                                         support    agree
# 1                                                         support    agree
# 2                                                         support    agree
# 3   That's what he deserves! No special treatment ...     support    agree
# 4   Well, serves him right! People like him need t...     support    agree
# ..                                                ...         ...      ...
# 83  I totally agree with you. Drinking and driving...     support    agree
# 84  I agree! It's frustrating seeing this happen i...     support    agree
# 85  No way! Everyone makes mistakes, don't pretend...        deny  against
# 86  That's crazy! It's unbelievable how some still...        deny  against
# 87  I couldn't agree more! Driving under the influ...     support    agree
#
#     repost  target_user                                     source_message  \
# 0     True           13  They dictate preventive detention for Pablo Ma...
# 1     True           16  They dictate preventive detention for Pablo Ma...
# 2     True           19  They dictate preventive detention for Pablo Ma...
# 3    False           16  They dictate preventive detention for Pablo Ma...
# 4    False           16  They dictate preventive detention for Pablo Ma...
# ..     ...          ...                                                ...
# 83   False           15  Absolutely, you're spot on. This guy needs to ...
# 84   False           14  No way! Are we really doing this again? It's 2...
# 85   False            7  Totally agree! Driving drunk is reckless and r...
# 86   False            7  Why are people still driving drunk in this day...
# 87   False            3  I totally agree. Drunk driving is a serious is...
#
#     source_user source_step  target_node
# 0             0           0            0
# 1             0           0            0
# 2            13       10:28            0
# 3            13       10:28            4
# 4            13       10:28            5
# ..          ...         ...          ...
# 83           17       18:08           84
# 84            7       21:33           85
# 85           19       15:50           86
# 86           12       21:05           87
# 87            4       19:10           88
#
# [88 rows x 12 columns]
